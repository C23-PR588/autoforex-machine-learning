# %%
from datetime import datetime
# %run function_and_library.ipynb
def parser(x):
    return datetime.strptime(x, '%Y-%m-%d')

# %%
md = [11,12,3,14,15,16,17,8,19,20]
eva = []

for i, model_number in enumerate(md):
    series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
    
    currency = series.columns.tolist()
    
    series = series.iloc[:,i]
            
    time = series.index

    # Preview the data
    plot_series(time, series, xlabel='Day', ylabel=f'{currency[i]}/IDR')
    
    split_time = 3000

    x_train = series[:split_time]
    time_train = time[:split_time]

    x_valid = series[split_time:]
    time_valid = time[split_time:]

    window_size = 30
    batch_size = 128
    shuffle_buffer_size = 1000

    train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)
    valid_set = windowed_dataset(x_valid, window_size, batch_size, shuffle_buffer_size)
    
    model = tf.keras.models.load_model(f"-second/{model_number}/")
    model.evaluate(valid_set)

    into_future = 7
    future_forecast = make_future_forecast(values=series,
                                           model=model,
                                           into_future=into_future,
                                           window_size=window_size)
    
    next_time_steps = pd.date_range(start=time[-1], periods=into_future+1)

    future_forecast = np.insert(future_forecast, 0, series[-1])
    
    plt.figure(figsize=(15, 7))
    plot_time_series(time, series, start=3630, format="-", label=f"Historical {currency[i]}/IDR")
    plot_time_series(next_time_steps, future_forecast, format="-", label=f"Forecast {currency[i]}/IDR")

#     eval_model = evaluate_predss(y_true=series,
#                                    y_pred=future_forecast)
    
#     eva.append(eval_model)
# Out:
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 9ms/step - loss: 94.4091 - mae: 94.9077
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 9ms/step - loss: 64.2026 - mae: 64.7004
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7592 - mae: 0.7062
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 11ms/step - loss: 109.8020 - mae: 110.3004
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 9ms/step - loss: 47.2820 - mae: 47.7804
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 9ms/step - loss: 75.1220 - mae: 75.6211
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 1s 9ms/step - loss: 9.2854 - mae: 9.7738
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 9ms/step - loss: 55.8514 - mae: 55.7042
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 17ms/step - loss: 13.5176 - mae: 14.0096
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# <ipython-input-12-30581c4aa019>:5: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = pd.read_csv('./currency_data_10_years.csv', header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
# 5/5 [==============================] - 0s 11ms/step - loss: 5.2791 - mae: 5.7263
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
# # Create a dictionary using the "md" list as keys and the "eva" list as values
# eva_data = {str(m): e for m, e in zip(md, eva)}

# # Convert the dictionary into a DataFrame
# eva_results = pd.DataFrame.from_dict(eva_data, orient='index')

# # Add a column for the row names
# eva_results.index.name = 'md'

# eva_results
